# %% [markdown]
# # Inspect

# %% [markdown]
# ## Setup

# %%
# Add the project root directory to sys.path to enable imports from the project
import sys
from pathlib import Path

project_root = Path().resolve().parent.parent
if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))

# %%
import duckdb
from constants.db import STAGE_3_DB

# %% [markdown]
# ## List product tables

# %%
with duckdb.connect(str(STAGE_3_DB)) as connection:
    tables = connection.sql("SHOW ALL TABLES").df()
tables
# Out:
#    database       schema                                               name  \
# 0   stage_3         main                                     farm_to_market
# 1   stage_3         main                                              farms
# 2   stage_3         main                                         int__farms
# 3   stage_3         main                                            markets
# 4   stage_3         main                                      stg__boroughs
# 5   stage_3         main                              stg__garden_block_lot
# 6   stage_3         main                                   stg__garden_info
# 7   stage_3         main                                       stg__markets
# 8   stage_3  main__tests                        farm_to_market_compound_key
# 9   stage_3  main__tests                not_null_farm_to_market_distance_ft
# 10  stage_3  main__tests                  not_null_farm_to_market_farm_name
# 11  stage_3  main__tests        not_null_farm_to_market_line_geometry_wgs84
# 12  stage_3  main__tests                not_null_farm_to_market_market_name
# 13  stage_3  main__tests                           not_null_farms_farm_name
# 14  stage_3  main__tests                       not_null_markets_market_name
# 15  stage_3  main__tests  source_not_null_external_sourc_d6702d345bd09d6...
# 16  stage_3  main__tests  source_not_null_external_source_Borough_Bounda...
# 17  stage_3  main__tests  source_not_null_external_source_GreenThumb_Blo...
# 18  stage_3  main__tests  source_not_null_external_source_GreenThumb_Gar...
# 19  stage_3  main__tests  source_unique_external_source_Borough_Boundari...
# 20  stage_3  main__tests  source_unique_external_source_GreenThumb_Garde...
# 21  stage_3  main__tests  source_unique_external_source_NYC_Farmers_Mark...
#
#                                          column_names  \
# 0   [market_name, farm_name, distance_ft, line_geo...
# 1                                         [farm_name]
# 2   [parksid, jurisdiction, address, cross_streets...
# 3                                       [market_name]
# 4                        [boro_name, boro_code, geom]
# 5      [parksid, block, lotnum, lotsize, areacovered]
# 6   [parksid, gardenname, jurisdiction, borough, a...
# 7   [market_name, accepts_ebt, distributes_health_...
# 8               [market_name, farm_name, distance_ft]
# 9   [market_name, farm_name, distance_ft, line_geo...
# 10  [market_name, farm_name, distance_ft, line_geo...
# 11  [market_name, farm_name, distance_ft, line_geo...
# 12  [market_name, farm_name, distance_ft, line_geo...
# 13                                        [farm_name]
# 14                                      [market_name]
# 15  [Borough, Market Name, Street Address, Communi...
# 16  [borocode, boroname, shape_area, shape_leng, g...
# 17     [parksid, block, lotnum, lotsize, areacovered]
# 18  [assemblydist, address, borough, communityboar...
# 19                          [unique_field, n_records]
# 20                          [unique_field, n_records]
# 21                          [unique_field, n_records]
#
#                                          column_types  temporary
# 0               [VARCHAR, VARCHAR, INTEGER, GEOMETRY]      False
# 1                                           [VARCHAR]      False
# 2   [VARCHAR, VARCHAR, VARCHAR, VARCHAR, BIGINT, B...      False
# 3                                           [VARCHAR]      False
# 4                        [VARCHAR, VARCHAR, GEOMETRY]      False
# 5          [VARCHAR, BIGINT, BIGINT, DOUBLE, VARCHAR]      False
# 6   [VARCHAR, VARCHAR, VARCHAR, VARCHAR, VARCHAR, ...      False
# 7   [VARCHAR, VARCHAR, BOOLEAN, VARCHAR, VARCHAR, ...      False
# 8                         [VARCHAR, VARCHAR, INTEGER]      False
# 9               [VARCHAR, VARCHAR, INTEGER, GEOMETRY]      False
# 10              [VARCHAR, VARCHAR, INTEGER, GEOMETRY]      False
# 11              [VARCHAR, VARCHAR, INTEGER, GEOMETRY]      False
# 12              [VARCHAR, VARCHAR, INTEGER, GEOMETRY]      False
# 13                                          [VARCHAR]      False
# 14                                          [VARCHAR]      False
# 15  [VARCHAR, VARCHAR, VARCHAR, BIGINT, DOUBLE, DO...      False
# 16     [VARCHAR, VARCHAR, VARCHAR, VARCHAR, GEOMETRY]      False
# 17         [VARCHAR, BIGINT, BIGINT, DOUBLE, VARCHAR]      False
# 18  [BIGINT, VARCHAR, VARCHAR, BIGINT, BIGINT, BIG...      False
# 19                                 [GEOMETRY, BIGINT]      False
# 20                                  [VARCHAR, BIGINT]      False
# 21                                  [VARCHAR, BIGINT]      False

# %% [markdown]
# ## Inspect product tables

# %%
with duckdb.connect(str(STAGE_3_DB)) as connection:
    farm_to_market = connection.sql("SELECT * FROM farm_to_market").df()
farm_to_market
# Out:
#                                     market_name  \
# 0                          New Roots Farm Stand
# 1                          Edgemere Farm Market
# 2      Hattie Carthan Herbal Apothecary/ Market
# 3                         Mott Haven Farm Stand
# 4                          Edgemere Farm Market
# ...                                         ...
# 92416                  Morris Heights Farmstand
# 92417                  Morris Heights Farmstand
# 92418                  Morris Heights Farmstand
# 92419                  Morris Heights Farmstand
# 92420                  Morris Heights Farmstand
#
#                                   farm_name  distance_ft  \
# 0                  New Roots Community Farm            0
# 1      Far Rock Urban Agro-Education Center          196
# 2                Hattie Carthan Herban Farm          382
# 3                               Padre Plaza          514
# 4                             Edgemere Farm         1347
# ...                                     ...          ...
# 92416              Skyline Community Garden    121188262
# 92417               Olivet Heavenly Harvest    121348728
# 92418             Moravian Community Garden    121367154
# 92419        West Brighton Community Garden    121372179
# 92420           Joe Holzka Community Garden    121382079
#
#                                      line_geometry_wgs84
# 0      [1, 4, 0, 0, 0, 0, 0, 0, 41, 73, 35, 66, 219, ...
# 1      [1, 4, 0, 0, 0, 0, 0, 0, 122, 97, 34, 66, 149,...
# 2      [1, 4, 0, 0, 0, 0, 0, 0, 152, 194, 34, 66, 29,...
# 3      [1, 4, 0, 0, 0, 0, 0, 0, 60, 59, 35, 66, 246, ...
# 4      [1, 4, 0, 0, 0, 0, 0, 0, 76, 97, 34, 66, 178, ...
# ...                                                  ...
# 92416  [1, 4, 0, 0, 0, 0, 0, 0, 97, 143, 34, 66, 210,...
# 92417  [1, 4, 0, 0, 0, 0, 0, 0, 82, 133, 34, 66, 96, ...
# 92418  [1, 4, 0, 0, 0, 0, 0, 0, 113, 116, 34, 66, 238...
# 92419  [1, 4, 0, 0, 0, 0, 0, 0, 107, 140, 34, 66, 90,...
# 92420  [1, 4, 0, 0, 0, 0, 0, 0, 28, 137, 34, 66, 48, ...
#
# [92421 rows x 4 columns]
