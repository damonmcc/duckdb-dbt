# %%
# Add the project root directory to sys.path to enable imports from the project
import sys
from pathlib import Path

project_root = Path().resolve().parent.parent
if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))

# %%
import duckdb
from constants.db import STAGE_3_DB

# %%
with duckdb.connect(str(STAGE_3_DB)) as connection:
    tables = connection.sql("SHOW ALL TABLES").df()
tables
# Out:
#    database               schema  \
# 0   stage_3          stage_3_dev
# 1   stage_3          stage_3_dev
# 2   stage_3          stage_3_dev
# 3   stage_3          stage_3_dev
# 4   stage_3          stage_3_dev
# 5   stage_3   stage_3_dev__tests
# 6   stage_3   stage_3_dev__tests
# 7   stage_3   stage_3_dev__tests
# 8   stage_3   stage_3_dev__tests
# 9   stage_3   stage_3_dev__tests
# 10  stage_3   stage_3_dev__tests
# 11  stage_3   stage_3_dev__tests
# 12  stage_3   stage_3_dev__tests
# 13  stage_3   stage_3_dev__tests
# 14  stage_3   stage_3_dev__tests
# 15  stage_3   stage_3_dev__tests
# 16  stage_3   stage_3_dev__tests
# 17  stage_3   stage_3_dev__tests
# 18  stage_3   stage_3_dev__tests
# 19  stage_3  stage_3_dev_product
# 20  stage_3  stage_3_dev_product
# 21  stage_3  stage_3_dev_product
#
#                                                  name  \
# 0                                          int__farms
# 1                                       stg__boroughs
# 2                               stg__garden_block_lot
# 3                                    stg__garden_info
# 4                                        stg__markets
# 5                         farm_to_market_compound_key
# 6                 not_null_farm_to_market_distance_ft
# 7                   not_null_farm_to_market_farm_name
# 8         not_null_farm_to_market_line_geometry_wgs84
# 9                 not_null_farm_to_market_market_name
# 10                           not_null_farms_farm_name
# 11                       not_null_markets_market_name
# 12  source_not_null_external_sourc_d6702d345bd09d6...
# 13  source_not_null_external_source_Borough_Bounda...
# 14  source_not_null_external_source_GreenThumb_Blo...
# 15  source_not_null_external_source_GreenThumb_Gar...
# 16  source_unique_external_source_Borough_Boundari...
# 17  source_unique_external_source_GreenThumb_Garde...
# 18  source_unique_external_source_NYC_Farmers_Mark...
# 19                                     farm_to_market
# 20                                              farms
# 21                                            markets
#
#                                          column_names  \
# 0   [parksid, jurisdiction, address, cross_streets...
# 1                        [boro_name, boro_code, geom]
# 2      [parksid, block, lotnum, lotsize, areacovered]
# 3   [parksid, gardenname, jurisdiction, borough, a...
# 4   [market_name, accepts_ebt, distributes_health_...
# 5               [market_name, farm_name, distance_ft]
# 6   [market_name, farm_name, distance_ft, line_geo...
# 7   [market_name, farm_name, distance_ft, line_geo...
# 8   [market_name, farm_name, distance_ft, line_geo...
# 9   [market_name, farm_name, distance_ft, line_geo...
# 10                                        [farm_name]
# 11                                      [market_name]
# 12  [Borough, Market Name, Street Address, Communi...
# 13  [borocode, boroname, shape_area, shape_leng, g...
# 14     [parksid, block, lotnum, lotsize, areacovered]
# 15  [assemblydist, address, borough, communityboar...
# 16                          [unique_field, n_records]
# 17                          [unique_field, n_records]
# 18                          [unique_field, n_records]
# 19  [market_name, farm_name, distance_ft, line_geo...
# 20                                        [farm_name]
# 21                                      [market_name]
#
#                                          column_types  temporary
# 0   [VARCHAR, VARCHAR, VARCHAR, VARCHAR, BIGINT, B...      False
# 1                        [VARCHAR, VARCHAR, GEOMETRY]      False
# 2          [VARCHAR, BIGINT, BIGINT, DOUBLE, VARCHAR]      False
# 3   [VARCHAR, VARCHAR, VARCHAR, VARCHAR, VARCHAR, ...      False
# 4   [VARCHAR, VARCHAR, BOOLEAN, VARCHAR, VARCHAR, ...      False
# 5                         [VARCHAR, VARCHAR, INTEGER]      False
# 6               [VARCHAR, VARCHAR, INTEGER, GEOMETRY]      False
# 7               [VARCHAR, VARCHAR, INTEGER, GEOMETRY]      False
# 8               [VARCHAR, VARCHAR, INTEGER, GEOMETRY]      False
# 9               [VARCHAR, VARCHAR, INTEGER, GEOMETRY]      False
# 10                                          [VARCHAR]      False
# 11                                          [VARCHAR]      False
# 12  [VARCHAR, VARCHAR, VARCHAR, BIGINT, DOUBLE, DO...      False
# 13     [VARCHAR, VARCHAR, VARCHAR, VARCHAR, GEOMETRY]      False
# 14         [VARCHAR, BIGINT, BIGINT, DOUBLE, VARCHAR]      False
# 15  [BIGINT, VARCHAR, VARCHAR, BIGINT, BIGINT, BIG...      False
# 16                                 [GEOMETRY, BIGINT]      False
# 17                                  [VARCHAR, BIGINT]      False
# 18                                  [VARCHAR, BIGINT]      False
# 19              [VARCHAR, VARCHAR, INTEGER, GEOMETRY]      False
# 20                                          [VARCHAR]      False
# 21                                          [VARCHAR]      False

# %%
product_tables = tables[tables.schema == "stage_3_dev_product"]
product_tables
# Out:
#    database               schema            name  \
# 19  stage_3  stage_3_dev_product  farm_to_market
# 20  stage_3  stage_3_dev_product           farms
# 21  stage_3  stage_3_dev_product         markets
#
#                                          column_names  \
# 19  [market_name, farm_name, distance_ft, line_geo...
# 20                                        [farm_name]
# 21                                      [market_name]
#
#                              column_types  temporary
# 19  [VARCHAR, VARCHAR, INTEGER, GEOMETRY]      False
# 20                              [VARCHAR]      False
# 21                              [VARCHAR]      False
